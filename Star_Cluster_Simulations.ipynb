# %% [markdown]
# <a href="https://colab.research.google.com/github/CarolineMNves/Star_Cluster_Simulations/blob/main/Star_Cluster_Simulations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
url = 'https://raw.githubusercontent.com/CarolineMNves/Star_Cluster_Simulations/main/c_0000.csv'
data = pd.read_csv(url)
data.head()
# Out:
#           x         y         z        vx        vy        vz         m  id
# 0  0.485939 -0.524359 -0.531982  0.461539 -0.033776 -0.322765  0.000016   1
# 1 -0.065961  0.080844 -0.276031 -0.575780  1.107815 -0.293408  0.000016   2
# 2 -0.034809  0.076795 -0.390880 -0.553991 -0.173861  0.059251  0.000016   3
# 3  1.502104  1.442983  1.449747 -0.090266  0.326612 -0.310594  0.000016   4
# 4 -0.009554  0.538341 -0.267264  0.011855 -0.011874 -0.405565  0.000016   5

# %%
data.tail()
# Out:
#               x         y         z        vx        vy        vz         m  \
# 63995 -0.515370  0.834457  1.609291  0.317309  0.082150 -0.514357  0.000016
# 63996  0.725611 -0.579058  0.973140  0.129194 -0.207819  0.259824  0.000016
# 63997 -0.175569 -0.397390  0.163967 -0.137939  0.234582 -0.060062  0.000016
# 63998  0.239999  0.625631  0.715540 -0.148245  0.351681  0.784334  0.000016
# 63999 -0.158667 -1.150932  0.237001 -0.396418 -0.076439 -0.445377  0.000016
#
#           id
# 63995  63996
# 63996  63997
# 63997  63998
# 63998  63999
# 63999  64000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64000 entries, 0 to 63999
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       64000 non-null  float64
#  1   y       64000 non-null  float64
#  2   z       64000 non-null  float64
#  3   vx      64000 non-null  float64
#  4   vy      64000 non-null  float64
#  5   vz      64000 non-null  float64
#  6   m       64000 non-null  float64
#  7   id      64000 non-null  int64
# dtypes: float64(7), int64(1)
# memory usage: 3.9 MB

# %%
data.isnull().sum()
# Out:
# x     0
# y     0
# z     0
# vx    0
# vy    0
# vz    0
# m     0
# id    0
# dtype: int64

# %%
stars = data.drop(columns= 'id')
stars.tail(2)
# Out:
#               x         y         z        vx        vy        vz         m
# 63998  0.239999  0.625631  0.715540 -0.148245  0.351681  0.784334  0.000016
# 63999 -0.158667 -1.150932  0.237001 -0.396418 -0.076439 -0.445377  0.000016

# %%
stars.shape
# Out:
# (64000, 7)

# %%
stars.describe()
# Out:
#                   x             y             z            vx            vy  \
# count  6.400000e+04  6.400000e+04  6.400000e+04  6.400000e+04  6.400000e+04
# mean  -1.176595e-10  3.412734e-10  2.464757e-10  1.101956e-10  2.103394e-10
# std    7.807475e-01  7.814718e-01  7.719907e-01  4.088337e-01  4.078873e-01
# min   -4.698981e+00 -5.095714e+00 -5.015129e+00 -1.619203e+00 -1.482613e+00
# 25%   -3.348222e-01 -3.366134e-01 -3.356278e-01 -2.697400e-01 -2.714544e-01
# 50%   -4.818202e-04 -4.321573e-04 -3.949339e-03 -2.090700e-04  1.419134e-03
# 75%    3.347058e-01  3.321014e-01  3.305091e-01  2.691137e-01  2.707544e-01
# max    5.401047e+00  5.680950e+00  4.762590e+00  1.547319e+00  1.584202e+00
#
#                  vz             m
# count  6.400000e+04  6.400000e+04
# mean   1.820625e-11  1.562500e-05
# std    4.080323e-01  6.776317e-21
# min   -1.685246e+00  1.562500e-05
# 25%   -2.709821e-01  1.562500e-05
# 50%    1.770830e-04  1.562500e-05
# 75%    2.700553e-01  1.562500e-05
# ...

# %%
plt.scatter(stars.x,stars.vx,color="red")
plt.xlabel("X positon of stars")
plt.ylabel("Velocity in X axis of stars")
plt.show()
